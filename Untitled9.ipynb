# %% [markdown]
# ## Understanding the data

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
employee = pd.read_csv("HR_Data_MSIS.csv")

# %%
employee
# Out:
#        employee_id         department  ... avg_training_score is_promoted
# 0            65438  Sales & Marketing  ...                 49           0
# 1            65141         Operations  ...                 60           0
# 2             7513  Sales & Marketing  ...                 50           0
# 3             2542  Sales & Marketing  ...                 50           0
# 4            48945         Technology  ...                 73           0
# ...            ...                ...  ...                ...         ...
# 54803         3030         Technology  ...                 78           0
# 54804        74592         Operations  ...                 56           0
# 54805        13918          Analytics  ...                 79           0
# 54806        13614  Sales & Marketing  ...                 45           0
# 54807        51526                 HR  ...                 49           0
#
# [54808 rows x 14 columns]

# %%
print(employee.head())
# Out:
#    employee_id         department  ... avg_training_score is_promoted
# 0        65438  Sales & Marketing  ...                 49           0
# 1        65141         Operations  ...                 60           0
# 2         7513  Sales & Marketing  ...                 50           0
# 3         2542  Sales & Marketing  ...                 50           0
# 4        48945         Technology  ...                 73           0
#
# [5 rows x 14 columns]

# %%
employee.describe()
# Out:
#         employee_id  no_of_trainings  ...  avg_training_score   is_promoted
# count  54808.000000     54808.000000  ...        54808.000000  54808.000000
# mean   39195.830627         1.253011  ...           63.386750      0.085170
# std    22586.581449         0.609264  ...           13.371559      0.279137
# min        1.000000         1.000000  ...           39.000000      0.000000
# 25%    19669.750000         1.000000  ...           51.000000      0.000000
# 50%    39225.500000         1.000000  ...           60.000000      0.000000
# 75%    58730.500000         1.000000  ...           76.000000      0.000000
# max    78298.000000        10.000000  ...           99.000000      1.000000
#
# [8 rows x 9 columns]

# %%
print(employee.columns)
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
employee.info
# Out:
# <bound method DataFrame.info of        employee_id         department  ... avg_training_score is_promoted
# 0            65438  Sales & Marketing  ...                 49           0
# 1            65141         Operations  ...                 60           0
# 2             7513  Sales & Marketing  ...                 50           0
# 3             2542  Sales & Marketing  ...                 50           0
# 4            48945         Technology  ...                 73           0
# ...            ...                ...  ...                ...         ...
# 54803         3030         Technology  ...                 78           0
# 54804        74592         Operations  ...                 56           0
# 54805        13918          Analytics  ...                 79           0
# 54806        13614  Sales & Marketing  ...                 45           0
# 54807        51526                 HR  ...                 49           0
#
# [54808 rows x 14 columns]>

# %%
employee.isnull()
# Out:
#        employee_id  department  ...  avg_training_score  is_promoted
# 0            False       False  ...               False        False
# 1            False       False  ...               False        False
# 2            False       False  ...               False        False
# 3            False       False  ...               False        False
# 4            False       False  ...               False        False
# ...            ...         ...  ...                 ...          ...
# 54803        False       False  ...               False        False
# 54804        False       False  ...               False        False
# 54805        False       False  ...               False        False
# 54806        False       False  ...               False        False
# 54807        False       False  ...               False        False
#
# [54808 rows x 14 columns]

# %% [markdown]
# # Cleaning the Data if any unwanted records are of no use

# %%
employee.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
HR = employee.drop(['region', 'no_of_trainings'], axis =1)
HR.head()
# Out:
#    employee_id         department  ... avg_training_score is_promoted
# 0        65438  Sales & Marketing  ...                 49           0
# 1        65141         Operations  ...                 60           0
# 2         7513  Sales & Marketing  ...                 50           0
# 3         2542  Sales & Marketing  ...                 50           0
# 4        48945         Technology  ...                 73           0
#
# [5 rows x 12 columns]

# %% [markdown]
# # Statisttical Analysis

# %%
corelation = HR.corr()
sns.heatmap(corelation,annot=True, linewidth = 0.5)

# %% [markdown]
# # Univariate Analysis

# %%
sns.pairplot(HR)

# %% [markdown]
# # Bivariate Analysis

# %%
sns.relplot(x='employee_id', y='department', data = HR)

# %%
sns.scatterplot(x = 'age', y = 'previous_year_rating', hue = 'gender', data = HR)

# %%
sns.distplot(HR['age'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(HR['age'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Fill in the missing values

# %%
HR.isnull().sum()
# Out:
# employee_id                0
# department                 0
# education               2409
# gender                     0
# recruitment_channel        0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
HR['education'].nunique()
# Out:
# 3

# %%
HR['previous_year_rating'].nunique()
# Out:
# 5

# %% [markdown]
# education and previous_year_rating both have null values

# %%
HR.fillna(method = 'ffill')
# Out:
#        employee_id         department  ... avg_training_score is_promoted
# 0            65438  Sales & Marketing  ...                 49           0
# 1            65141         Operations  ...                 60           0
# 2             7513  Sales & Marketing  ...                 50           0
# 3             2542  Sales & Marketing  ...                 50           0
# 4            48945         Technology  ...                 73           0
# ...            ...                ...  ...                ...         ...
# 54803         3030         Technology  ...                 78           0
# 54804        74592         Operations  ...                 56           0
# 54805        13918          Analytics  ...                 79           0
# 54806        13614  Sales & Marketing  ...                 45           0
# 54807        51526                 HR  ...                 49           0
#
# [54808 rows x 12 columns]

# %%
x.fillna(employee['age'].mean())
# Out:
#        employee_id         department  ... avg_training_score is_promoted
# 0            65438  Sales & Marketing  ...                 49           0
# 1            65141         Operations  ...                 60           0
# 2             7513  Sales & Marketing  ...                 50           0
# 3             2542  Sales & Marketing  ...                 50           0
# 4            48945         Technology  ...                 73           0
# ...            ...                ...  ...                ...         ...
# 54803         3030         Technology  ...                 78           0
# 54804        74592         Operations  ...                 56           0
# 54805        13918          Analytics  ...                 79           0
# 54806        13614  Sales & Marketing  ...                 45           0
# 54807        51526                 HR  ...                 49           0
#
# [54808 rows x 12 columns]
